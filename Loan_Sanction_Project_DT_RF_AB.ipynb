# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib as plt

# %%
df=pd.read_csv('https://raw.githubusercontent.com/Datacouncil11/Loan_sancion_project/main/loan-train.csv')

# %%
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
#EDA

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             601 non-null    object
#  2   Married            611 non-null    object
#  3   Dependents         599 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      582 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         592 non-null    float64
#  9   Loan_Amount_Term   600 non-null    float64
#  10  Credit_History     564 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.5+ KB

# %%
df.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  592.000000         600.00000
# mean       5403.459283        1621.245798  146.412162         342.00000
# std        6109.041673        2926.248369   85.587325          65.12041
# min         150.000000           0.000000    9.000000          12.00000
# 25%        2877.500000           0.000000  100.000000         360.00000
# 50%        3812.500000        1188.500000  128.000000         360.00000
# 75%        5795.000000        2297.250000  168.000000         360.00000
# max       81000.000000       41667.000000  700.000000         480.00000
#
#        Credit_History
# count      564.000000
# mean         0.842199
# std          0.364878
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
df.shape
# Out:
# (614, 13)

# %%
df['Gender'].unique()
# Out:
# array(['Male', 'Female', nan], dtype=object)

# %%
d1=df

# %%
d1.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
for i in d1.columns:
    print("Column Name",i)
    print('unique value in',i,d1[i].unique())
    print("*"*60)
# Out:
# Column Name Loan_ID
# unique value in Loan_ID ['LP001002' 'LP001003' 'LP001005' 'LP001006' 'LP001008' 'LP001011'
#  'LP001013' 'LP001014' 'LP001018' 'LP001020' 'LP001024' 'LP001027'
#  'LP001028' 'LP001029' 'LP001030' 'LP001032' 'LP001034' 'LP001036'
#  'LP001038' 'LP001041' 'LP001043' 'LP001046' 'LP001047' 'LP001050'
#  'LP001052' 'LP001066' 'LP001068' 'LP001073' 'LP001086' 'LP001087'
#  'LP001091' 'LP001095' 'LP001097' 'LP001098' 'LP001100' 'LP001106'
#  'LP001109' 'LP001112' 'LP001114' 'LP001116' 'LP001119' 'LP001120'
#  'LP001123' 'LP001131' 'LP001136' 'LP001137' 'LP001138' 'LP001144'
#  'LP001146' 'LP001151' 'LP001155' 'LP001157' 'LP001164' 'LP001179'
#  'LP001186' 'LP001194' 'LP001195' 'LP001197' 'LP001198' 'LP001199'
#  'LP001205' 'LP001206' 'LP001207' 'LP001213' 'LP001222' 'LP001225'
#  'LP001228' 'LP001233' 'LP001238' 'LP001241' 'LP001243' 'LP001245'
#  'LP001248' 'LP001250' 'LP001253' 'LP001255' 'LP001256' 'LP001259'
# ...

# %%
for i in d1.columns:
    print('Column name is',i)
    print("Null values in",i,d1[i].isnull().sum())
    print("*"*60)
# Out:
# Column name is Loan_ID
# Null values in Loan_ID 0
# ************************************************************
# Column name is Gender
# Null values in Gender 13
# ************************************************************
# Column name is Married
# Null values in Married 3
# ************************************************************
# Column name is Dependents
# Null values in Dependents 15
# ************************************************************
# Column name is Education
# Null values in Education 0
# ************************************************************
# Column name is Self_Employed
# Null values in Self_Employed 32
# ************************************************************
# Column name is ApplicantIncome
# Null values in ApplicantIncome 0
# ************************************************************
# Column name is CoapplicantIncome
# Null values in CoapplicantIncome 0
# ************************************************************
# ...

# %%
for i in d1.columns:
    print('columns name is' ,i)
    print(d1[i].describe())
    print("*"*70)
# Out:
# columns name is Loan_ID
# count          614
# unique         614
# top       LP001002
# freq             1
# Name: Loan_ID, dtype: object
# **********************************************************************
# columns name is Gender
# count      601
# unique       2
# top       Male
# freq       489
# Name: Gender, dtype: object
# **********************************************************************
# columns name is Married
# count     611
# unique      2
# top       Yes
# freq      398
# Name: Married, dtype: object
# **********************************************************************
# columns name is Dependents
# count     599
# unique      4
# top         0
# freq      345
# Name: Dependents, dtype: object
# **********************************************************************
# columns name is Education
# count          614
# unique           2
# top       Graduate
# freq           480
# Name: Education, dtype: object
# ...

# %%
#Duplicate value

# %%
df[d1.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Loan_ID, Gender, Married, Dependents, Education, Self_Employed, ApplicantIncome, CoapplicantIncome, LoanAmount, Loan_Amount_Term, Credit_History, Property_Area, Loan_Status]
# Index: []

# %%
#felling missing value

# %%
d1['Gender'].isnull().sum()
# Out:
# 13

# %%
d1['Gender'].mode()
# Out:
# 0    Male
# Name: Gender, dtype: object

# %%
mode_genders=d1['Gender'].mode()[0]=d1['Gender'].mode()[0]

# %%
mode_genders
# Out:
# 'Male'

# %%
d1['Gender'].fillna(mode_genders,inplace=True)

# %%
d1['Gender'].isnull().sum()
# Out:
# 0

# %%
d1['Married'].isnull().sum()
# Out:
# 3

# %%
mode_married=d1['Married'].mode()

# %%
mode_married
# Out:
# 0    Yes
# Name: Married, dtype: object

# %%
mode_married=d1['Married'].mode()[0]

# %%
d1['Married'].fillna(mode_married,inplace=True)

# %%
d1['Married'].isnull().sum()
# Out:
# 0

# %%
d1['Dependents'].isnull().sum()
# Out:
# 15

# %%
mode_Dependents=d1['Dependents'].mode()[0]

# %%
d1['Dependents'].fillna(mode_Dependents,inplace=True)

# %%
d1['Dependents'].isnull().sum()
# Out:
# 0

# %%
mode_Education=d1['Education'].mode([0])

# %%
d1['Education'].fillna(mode_Education,inplace=True)

# %%
d1['Education'].isnull().sum()
# Out:
# 0

# %%
mode_Self_Employed=d1['Self_Employed'].mode()[0]

# %%
mode_Self_Employed
# Out:
# 'No'

# %%
d1['Self_Employed'].fillna(mode_Self_Employed,inplace=True)

# %%
d1['Self_Employed'].isnull().sum()
# Out:
# 0

# %%
mean_LoanAmount=d1['LoanAmount'].mean()

# %%
mean_LoanAmount
# Out:
# 146.41216216216216

# %%
d1['LoanAmount'].fillna(mean_LoanAmount,inplace=True)

# %%
d1['LoanAmount'].isnull().sum()
# Out:
# 0

# %%
d1['Loan_Amount_Term'].isnull().sum()
# Out:
# 14

# %%
mean_Loan_Amount_Term=d1['Loan_Amount_Term'].mean()

# %%
mean_Loan_Amount_Term
# Out:
# 342.0

# %%
d1['Loan_Amount_Term'].fillna(mean_Loan_Amount_Term,inplace=True)

# %%
d1['Loan_Amount_Term'].isnull().sum()
# Out:
# 0

# %%
mode_Credit_History=d1['Credit_History'].mode()[0]

# %%
mode_Credit_History
# Out:
# 1.0

# %%
d1['Credit_History'].fillna(mode_Credit_History,inplace=True)

# %%
d1['Credit_History'].isnull().sum()
# Out:
# 0

# %%
#mapping

# %%
from sklearn.preprocessing import LabelEncoder

# %%
#applying lable encoding

# %%
label_encoder=LabelEncoder()

# %%
d1['Gender_lable']=label_encoder.fit_transform(d1['Gender'])

# %%
d1['Married_label']=label_encoder.fit_transform(d1['Married'])

# %%
d1['Education_label']=label_encoder.fit_transform(d1['Education'])

# %%
d1['Dependents_label']=label_encoder.fit_transform(d1['Dependents'])

# %%
d1['Self_Employed_label']=label_encoder.fit_transform(d1['Self_Employed'])

# %%
d1['Credit_History_label']=label_encoder.fit_transform(d1['Credit_History'])

# %%
d1['Property_Area_label']=label_encoder.fit_transform(d1['Property_Area'])

# %%
#removing column

# %%
d1.drop('Gender',axis=1,inplace=True)

# %%
d1.drop('Married',axis=1,inplace=True)
d1.drop('Dependents',axis=1,inplace=True)
d1.drop('Self_Employed',axis=1,inplace=True)
d1.drop('Education',axis=1,inplace=True)
d1.drop('Credit_History',axis=1,inplace=True)
d1.drop('Property_Area',axis=1,inplace=True)

# %%
d1.drop('Loan_ID',axis=1,inplace=True)

# %%
d1['Loan_Status_1']=d1['Loan_Status']

# %%
d1.drop('Loan_Status',axis=1,inplace=True)

# %%
d1.head()
# Out:
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0  146.412162             360.0
# 1             4583             1508.0  128.000000             360.0
# 2             3000                0.0   66.000000             360.0
# 3             2583             2358.0  120.000000             360.0
# 4             6000                0.0  141.000000             360.0
#
#    Gender_lable  Married_label  Education_label  Dependents_label  \
# 0             1              0                0                 0
# 1             1              1                0                 1
# 2             1              1                0                 0
# 3             1              1                1                 0
# 4             1              0                0                 0
#
#    Self_Employed_label  Credit_History_label  Property_Area_label  \
# 0                    0                     1                    2
# ...

# %%
#dependent $ independent

# %%
X=d1.iloc[:,:-1]

# %%
y=d1.iloc[:,-1]

# %%
y.head()
# Out:
# 0    Y
# 1    N
# 2    Y
# 3    Y
# 4    Y
# Name: Loan_Status_1, dtype: object

# %%
d1['Dependents_label'].unique()
# Out:
# array([0, 1, 2, 3])

# %%
#dividing data into train test split

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.33,random_state=42)

# %%
X_train.head()
# Out:
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 244             3406             4417.0       123.0             360.0
# 393             1993             1625.0       113.0             180.0
# 310             2917                0.0        84.0             360.0
# 408             8300                0.0       152.0             300.0
# 572            16666                0.0       275.0             360.0
#
#      Gender_lable  Married_label  Education_label  Dependents_label  \
# 244             1              1                1                 0
# 393             1              1                1                 2
# 310             0              0                0                 0
# 408             1              1                0                 1
# 572             1              1                0                 2
#
#      Self_Employed_label  Credit_History_label  Property_Area_label
# ...

# %%
y_train.head()
# Out:
# 244    Y
# 393    Y
# 310    Y
# 408    N
# 572    Y
# Name: Loan_Status_1, dtype: object

# %%
from sklearn.linear_model import LogisticRegression

# %%
logistic_reg=LogisticRegression()

# %%
logistic_reg.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
#predection

# %%
y_pred = logistic_reg.predict(X_test)

# %%
#evaluation
from sklearn.metrics import accuracy_score

# %%
accuracy=accuracy_score(y_test,y_pred)

# %%
accuracy
# Out:
# 0.7980295566502463

# %%
#confusion matrices

# %%
from sklearn.metrics import confusion_matrix

# %%
con_matrx=confusion_matrix(y_test,y_pred)

# %%
con_matrx
# Out:
# array([[ 33,  39],
#        [  2, 129]], dtype=int64)

# %%
# report

# %%
from sklearn.metrics import classification_report

# %%
class_report=classification_report(y_test,y_pred)

# %%
print(class_report)
# Out:
#               precision    recall  f1-score   support
#
#            N       0.94      0.46      0.62        72
#            Y       0.77      0.98      0.86       131
#
#     accuracy                           0.80       203
#    macro avg       0.86      0.72      0.74       203
# weighted avg       0.83      0.80      0.78       203

# %%
#visulization
import matplotlib.pyplot as plt

# %%
sns.heatmap(con_matrx,annot=True,fmt='d',cmap='Blues')
plt.xlabel("pridected")
plt.ylabel("Actual")
plt.title("confusion matrix")
plt.show()

# %%
#decision Tree ,Random Forest ,Adaboost

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier,AdaBoostClassifier

# %%
dtree = DecisionTreeClassifier(random_state=43)

# %%
dtree.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(random_state=43)

# %%
y_pred_dt=dtree.predict(X_test)

# %%
accuracy_dt=accuracy_score(y_test,y_pred_dt)

# %%
accuracy_dt
# Out:
# 0.6945812807881774

# %%
#Random forest

# %%
rf=RandomForestClassifier(n_estimators=100,random_state=46)

# %%
rf.fit(X_train,y_train)
# Out:
# RandomForestClassifier(random_state=46)

# %%
y_pred_rf=rf.predict(X_test)

# %%
accuracy_score_rf=accuracy_score(y_test,y_pred)

# %%
accuracy_score_rf
# Out:
# 0.7980295566502463

# %%
#Adaboost

# %%
ad=AdaBoostClassifier(n_estimators=100,random_state=46)

# %%
ad.fit(X_train,y_train)
# Out:
# AdaBoostClassifier(n_estimators=100, random_state=46)

# %%
y_pred_ad=ad.predict(X_test)

# %%
accuracy_score_ad=accuracy_score(y_pred,y_pred_ad)

# %%
accuracy_score_ad
# Out:
# 0.9113300492610837

# %%
print('Accuracy of Logistic Regresion:',accuracy)
print('Accuracy of Decision tree:',accuracy_dt)
print('Accuracy of Random forest:',accuracy_score_rf)
print('Accuracy of adaboost:',accuracy_score_ad)
# Out:
# Accuracy of Logistic Regresion: 0.7980295566502463
# Accuracy of Decision tree: 0.6945812807881774
# Accuracy of Random forest: 0.7980295566502463
# Accuracy of adaboost: 0.9113300492610837

# %%
#END
